# %%
from scipy.stats import poisson

# %%
from scipy.stats import poisson

# Average rate (λ)
lam =6

# Probability of exactly 2 events
prob = poisson.pmf(5, lam)
print("Probability:", prob)
# Out:
# Probability: 0.16062314104797995
