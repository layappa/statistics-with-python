# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # data creation

# %%
data = pd.DataFrame({
    "ID": range(1, 101),
    "Gender": np.random.choice(["Male", "Female"], 100),
    "Score": np.random.randint(40, 100, 100)
})

# %% [markdown]
# # systmatic sampling

# %%
k=len(data)//10
systmatic_sample=data.iloc[::k]
systmatic_sample
# Out:
#     ID  Gender  Score
# 0    1  Female     90
# 10  11    Male     66
# 20  21    Male     74
# 30  31    Male     67
# 40  41    Male     92
# 50  51  Female     95
# 60  61  Female     99
# 70  71  Female     88
# 80  81    Male     56
# 90  91    Male     80
